# %% [markdown]
# <a href="https://colab.research.google.com/github/sarah2005-cyber/auspex/blob/main/DAEF_VS_Model_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !find '/content/spm/spec_1024_spm/stego' -type f | wc -l
# Out:
# 10000

# %%
# !pip install librosa scikit-learn tqdm

# %%
# !python test_pipeline.py
# Out:
# ...
# DAEF-VS Pipeline Test
# ...
#
# [1/5] Creating dummy SpecDataset...
# ✓ Created dummy datasets:
#   Cover: 50 samples
#   Stego: 50 samples
#
# [2/5] Testing feature extraction...
#   Input shapes:
#     spec1024: torch.Size([1, 513, 100])
#     spec512: torch.Size([1, 257, 100])
# ✓ Feature extraction successful!
#   Output shapes:
#     feat_1024: (97, 16)
#     feat_512: (97, 16)
#   Feature dimension: 16
#
# [3/5] Testing dataset wrapper...
# ✓ Dataset wrapper created!
#   Dataset size: 50
#   Sample features shape: torch.Size([97, 32])
#   Sample label: 0
#
# [4/5] Testing DataLoader...
# ✓ DataLoader working!
#   Batch features shape: torch.Size([8, 97, 32])
#   Batch labels shape: torch.Size([8])
#   Sequence lengths: tensor([97, 97, 97, 97, 97, 97, 97, 97])
#
# [5/5] Testing model forward pass...
# ✓ Model created!
#   Parameters: 697,346
#   Classification output shape: torch.Size([8, 2])
#   Logits shape: torch.Size([8, 2])
#   Embeddings shape: torch.Size([8, 64])
# ...

# %%
# !mkdir /content/spm/
# Out:
# mkdir: cannot create directory ‘/content/spm/’: File exists

# %%
# !cp -r "/content/drive/MyDrive/IIT - University of Westminster Material/VStego800K dataset/Selected_Subset/spec_1024_spm" \
      /content/spm/spec_1024_spm

# %%
# !python daefvs_baseline_train.py \
    --use_existing_splits \
    --split_indices_path "/content/drive/MyDrive/IIT - University of Westminster Material/VStego800K dataset/indices_v2/split_indices_baseline_full_model_seed42.json" \
    --cover_1024_path "/content/spm/spec_1024_spm/cover" \
    --cover_512_path "/content/spm/spec_512_spm/cover" \
    --stego_1024_path "/content/spm/spec_1024_spm/stego" \
    --stego_512_path "/content/spm/spec_512_spm/stego" \
    --batch_size 64 \
    --epochs 30 \
    --checkpoint_path "/content/drive/MyDrive/IIT - University of Westminster Material/VStego800K dataset/comparison/daefvs_baseline_best.pth" \
    --results_path "/content/drive/MyDrive/IIT - University of Westminster Material/VStego800K dataset/comparison/daefvs_baseline_results.json"
# Out:
# ...
# DAEF-VS Baseline Training
# ...
# Device: cpu
# Seed: 42
#
# ...
# Loading your datasets (using YOUR splits!)...
# ...
# ✓ Loaded datasets:
#   Cover: 10000 samples
#   Stego: 10000 samples
#
# ✓ Using YOUR existing splits from: /content/drive/MyDrive/IIT - University of Westminster Material/VStego800K dataset/indices_v2/split_indices_baseline_full_model_seed42.json
#   Train: 14000 samples
#   Val: 3000 samples
#   Test: 3000 samples
#
# ...
# Wrapping with DAEF-VS feature extraction...
# ...
# ✓ Feature dimension: 16
#   (Using both streams: 32 total)
#
# ✓ DataLoaders created:
#   Train batches: 219
#   Val batches: 47
#   Test batches: 47
#
# ...
# Model Architecture:
# ...
# Input dimension: 32
# Hidden dimension: 256
# Num layers: 4
# Num heads: 8
# Pooling: mean
# Total parameters: 3,299,842
#
# ...
# Starting Training...
# ...
#
#
# Epoch 1/30
# ------------------------------------------------------------
# ...
